# %%
import libraries as lb

# %%
consumption_data = lb.pd.read_csv('dataset/consumption_facility_cleaned.csv')
consumption_data.head()
# Out:
#   Patient_ID  Region Medicine_ID                            DrugName  \
# 0       P001  Indore   M07208F17     LIGNOCAINE HYDROCHLORIDE 2% INJ
# 1       P001  Indore   M09598F70                  ADRENALINE INJ 1ML
# 2       P001  Indore   M359D09B5               LIQUID PARAFFIN 100ML
# 3       P001  Indore   M524E5E35                   ESOMEPRAZOLE 40MG
# 4       P001  Indore   M589A5AA4   WATER FOR INJECTION 10ML SOLUTION
#
#    Daily_Consumption_Units  Out_of_Stock_Days  Wastage_Units  Bed_Days  \
# 0                      0.5                  0              0         2
# 1                      2.0                  0              0         2
# 2                      0.0                  0              1         2
# 3                      0.5                  0              0         2
# 4                      3.0                  0              0         2
#
#   Supplies_Used  Total_Consumption  Stockout_Flag  Wastage_Flag  \
# ...

# %%
demand_data=lb.pd.read_csv("dataset/demand_sales_cleaned.csv")
demand_data.head()
# Out:
#   Order_ID  Order_Date Patient_ID          Dept     Specialisation  \
# 0   O00001  2024-06-01       P045   Department1    Specialisation6
# 1   O00002  2024-09-18       P387   Department1    Specialisation7
# 2   O00003  2024-11-03       P328   Department3    Specialisation2
# 3   O00004  2024-01-15       P220   Department1   Specialisation40
# 4   O00005  2024-09-27       P217   Department1    Specialisation5
#
#   Medicine_ID                            DrugName Formulation  Quantity  \
# 0   M1CA76D1B           ZINC ACETATE 20MG/5ML SYP       Form1         1
# 1   M318FBCBC     CEFTAZIDIME 2GM+AVIBACTAM 500MG       Form1         1
# 2   M82D7852E              EPTIFIBATIDE 0.75MG/ML       Form2         1
# 3   MCA6D8773   WATER FOR INJECTION 10ML SOLUTION       Form1         2
# 4   M18E1DD4A                       LORAZEPAM 1MG       Form1         1
#
#    ReturnQuantity  ...  RtnMRP  Order_Status  Delivery_Date Lead_Time_Days  \
# ...

# %%
inventory_stock_data=lb.pd.read_csv("dataset/inventory_stock_cleaned.csv")
inventory_stock_data.head()
# Out:
#   Medicine_ID                            DrugName Formulation    Category  \
# 0   M07208F17     LIGNOCAINE HYDROCHLORIDE 2% INJ   Injection  Parenteral
# 1   M09598F70                  ADRENALINE INJ 1ML   Injection  Parenteral
# 2   M359D09B5               LIQUID PARAFFIN 100ML       Other       Other
# 3   M524E5E35                   ESOMEPRAZOLE 40MG       Other       Other
# 4   M589A5AA4   WATER FOR INJECTION 10ML SOLUTION   Injection  Parenteral
#
#     Batch_No Manufacture_Date Expiry_Date  Current_Stock  Min_Required  \
# 0  BATCH1803       2023-02-21  2024-02-21            230            32
# 1  BATCH7964       2023-08-12  2024-08-11             78            79
# 2  BATCH6890       2023-06-24  2025-06-23            195            69
# 3  BATCH4949       2023-02-19  2025-02-18            260            43
# 4  BATCH4896       2023-03-03  2024-03-02            476            53
#
#    Max_Capacity  ...  Restock_Lead_Time_Days  Reorder_Level  Stock_Cover_Days  \
# ...

# %%
supplier_procurement_data=lb.pd.read_csv("dataset/supplier_procurement_cleaned.csv")
supplier_procurement_data.head()
# Out:
#   Supplier_ID Supplier_Name Region  Avg_Lead_Time_Days  Reliability_Score  \
# 0        V923    Supplier_1  Delhi                  12                4.2
# 1        V775    Supplier_2  Delhi                   9                4.6
# 2        V307    Supplier_3   Pune                   8                4.1
# 3        V270    Supplier_4   Pune                   9                3.8
# 4        V711    Supplier_5   Pune                  12                4.4
#
#    Cost_Per_Item Last_Order_Date Next_Delivery_Date  On_Time_Delivery_Rate  \
# 0         116.21      2024-01-19         2024-01-31                     75
# 1         113.26      2024-11-14         2024-11-23                     73
# 2         118.98      2024-09-18         2024-09-26                     80
# 3         103.85      2024-05-24         2024-06-02                     71
# 4         112.12      2024-08-10         2024-08-22                     71
#
# ...
